# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
file_to_load = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(file_to_load)
purchase_data.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
player_count = pd.DataFrame({"Total Players":[len(list(purchase_data["SN"].unique()))]})
player_count
# Out:
#    Total Players
# 0            576

# %%
num_item = len(list(purchase_data["Item Name"].unique()))
num_purchases = sum(purchase_data["Item Name"].value_counts())
avg_price = purchase_data["Price"].mean()
total_revenue = sum(purchase_data["Price"])
purchase_analysis_df = pd.DataFrame({'Number of Unique Items': [num_item],
                                    'Average Price': [avg_price],
                                    'Number of Purchases':[num_purchases],
                                    'Total Revenue': [total_revenue]


})
purchase_analysis_df.style.format({'Average Price':"${:,.2f}", 'Total Revenue': '${:,.2f}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_8a2df">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8a2df_level0_col0" class="col_heading level0 col0" >Number of Unique Items</th>
#       <th id="T_8a2df_level0_col1" class="col_heading level0 col1" >Average Price</th>
#       <th id="T_8a2df_level0_col2" class="col_heading level0 col2" >Number of Purchases</th>
#       <th id="T_8a2df_level0_col3" class="col_heading level0 col3" >Total Revenue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8a2df_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8a2df_row0_col0" class="data row0 col0" >179</td>
#       <td id="T_8a2df_row0_col1" class="data row0 col1" >$3.05</td>
#       <td id="T_8a2df_row0_col2" class="data row0 col2" >780</td>
#       <td id="T_8a2df_row0_col3" class="data row0 col3" >$2,379.77</td>
#     </tr>
#   </tbody>
# </table>

# %%
total_players = len(purchase_data["SN"].value_counts())
gender_purchase_df = purchase_data.groupby("Gender")
total_count_gender = gender_purchase_df.nunique()["SN"]
per_gender = total_count_gender/(total_players) *100

# 
gender_demographics = pd.DataFrame({'Total Count': total_count_gender,
                                    'Percentage of Players': per_gender

})
gender_demographics.sort_values(["Total Count"], ascending = False).style.format({"Percentage of Players":"{:.2f}%"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_5b65a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5b65a_level0_col0" class="col_heading level0 col0" >Total Count</th>
#       <th id="T_5b65a_level0_col1" class="col_heading level0 col1" >Percentage of Players</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Gender</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b65a_level0_row0" class="row_heading level0 row0" >Male</th>
#       <td id="T_5b65a_row0_col0" class="data row0 col0" >484</td>
#       <td id="T_5b65a_row0_col1" class="data row0 col1" >84.03%</td>
#     </tr>
#     <tr>
#       <th id="T_5b65a_level0_row1" class="row_heading level0 row1" >Female</th>
#       <td id="T_5b65a_row1_col0" class="data row1 col0" >81</td>
#       <td id="T_5b65a_row1_col1" class="data row1 col1" >14.06%</td>
#     </tr>
#     <tr>
#       <th id="T_5b65a_level0_row2" class="row_heading level0 row2" >Other / Non-Disclosed</th>
#       <td id="T_5b65a_row2_col0" class="data row2 col0" >11</td>
#       <td id="T_5b65a_row2_col1" class="data row2 col1" >1.91%</td>
#     </tr>
#   </tbody>
# </table>

# %%
purchase_count = purchase_data["Gender"].value_counts()
gen_avg_price = gender_purchase_df["Price"].mean()
gen_total_purchase = gender_purchase_df["Price"].sum()
gen_avg_purchase_per_person = gen_total_purchase/total_count_gender

gen_purchase_analysis_df = pd.DataFrame({'Purchase Count': purchase_count,
                                        'Average Purchase Price': gen_avg_price,
                                        'Total Purchase':gen_total_purchase,
                                        'Avg Total Purchase per Person': gen_avg_purchase_per_person

})
gen_purchase_analysis_df.style.format({"Average Purchase Price": "${:.2f}", 
                                     "Total Purchase": "${:.2f}",
                                     "Avg Total Purchase per Person": "${:.2f}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_d27bc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d27bc_level0_col0" class="col_heading level0 col0" >Purchase Count</th>
#       <th id="T_d27bc_level0_col1" class="col_heading level0 col1" >Average Purchase Price</th>
#       <th id="T_d27bc_level0_col2" class="col_heading level0 col2" >Total Purchase</th>
#       <th id="T_d27bc_level0_col3" class="col_heading level0 col3" >Avg Total Purchase per Person</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d27bc_level0_row0" class="row_heading level0 row0" >Female</th>
#       <td id="T_d27bc_row0_col0" class="data row0 col0" >113</td>
#       <td id="T_d27bc_row0_col1" class="data row0 col1" >$3.20</td>
#       <td id="T_d27bc_row0_col2" class="data row0 col2" >$361.94</td>
#       <td id="T_d27bc_row0_col3" class="data row0 col3" >$4.47</td>
#     </tr>
#     <tr>
#       <th id="T_d27bc_level0_row1" class="row_heading level0 row1" >Male</th>
#       <td id="T_d27bc_row1_col0" class="data row1 col0" >652</td>
#       <td id="T_d27bc_row1_col1" class="data row1 col1" >$3.02</td>
#       <td id="T_d27bc_row1_col2" class="data row1 col2" >$1967.64</td>
#       <td id="T_d27bc_row1_col3" class="data row1 col3" >$4.07</td>
#     </tr>
#     <tr>
#       <th id="T_d27bc_level0_row2" class="row_heading level0 row2" >Other / Non-Disclosed</th>
#       <td id="T_d27bc_row2_col0" class="data row2 col0" >15</td>
#       <td id="T_d27bc_row2_col1" class="data row2 col1" >$3.35</td>
#       <td id="T_d27bc_row2_col2" class="data row2 col2" >$50.19</td>
#       <td id="T_d27bc_row2_col3" class="data row2 col3" >$4.56</td>
#     </tr>
#   </tbody>
# </table>

# %%
bins_age = [ 0, 9.90, 14.90, 19.90, 24.90, 29.90, 34.90, 39.90, 99999]
lables_age = ["<10","10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+" ]
purchase_data["Age Range"] = pd.cut(purchase_data["Age"], bins_age, labels=lables_age)
age_demographics = purchase_data.groupby("Age Range")
total_count_age = age_demographics["SN"].nunique()
per_player  = total_count_age/total_players *100
age_demographics_df = pd.DataFrame({'Total Count': total_count_age,
                                    'Percentage of Players':per_player

})
age_demographics_df.style.format({"Percentage of Players":"{:,.2f}%"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_7a608">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7a608_level0_col0" class="col_heading level0 col0" >Total Count</th>
#       <th id="T_7a608_level0_col1" class="col_heading level0 col1" >Percentage of Players</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Age Range</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a608_level0_row0" class="row_heading level0 row0" ><10</th>
#       <td id="T_7a608_row0_col0" class="data row0 col0" >17</td>
#       <td id="T_7a608_row0_col1" class="data row0 col1" >2.95%</td>
#     </tr>
#     <tr>
#       <th id="T_7a608_level0_row1" class="row_heading level0 row1" >10-14</th>
#       <td id="T_7a608_row1_col0" class="data row1 col0" >22</td>
#       <td id="T_7a608_row1_col1" class="data row1 col1" >3.82%</td>
#     </tr>
#     <tr>
#       <th id="T_7a608_level0_row2" class="row_heading level0 row2" >15-19</th>
#       <td id="T_7a608_row2_col0" class="data row2 col0" >107</td>
#       <td id="T_7a608_row2_col1" class="data row2 col1" >18.58%</td>
#     </tr>
#     <tr>
#       <th id="T_7a608_level0_row3" class="row_heading level0 row3" >20-24</th>
#       <td id="T_7a608_row3_col0" class="data row3 col0" >258</td>
#       <td id="T_7a608_row3_col1" class="data row3 col1" >44.79%</td>
#     </tr>
#     <tr>
#       <th id="T_7a608_level0_row4" class="row_heading level0 row4" >25-29</th>
#       <td id="T_7a608_row4_col0" class="data row4 col0" >77</td>
#       <td id="T_7a608_row4_col1" class="data row4 col1" >13.37%</td>
#     </tr>
#     <tr>
#       <th id="T_7a608_level0_row5" class="row_heading level0 row5" >30-34</th>
#       <td id="T_7a608_row5_col0" class="data row5 col0" >52</td>
#       <td id="T_7a608_row5_col1" class="data row5 col1" >9.03%</td>
#     </tr>
#     <tr>
#       <th id="T_7a608_level0_row6" class="row_heading level0 row6" >35-39</th>
#       <td id="T_7a608_row6_col0" class="data row6 col0" >31</td>
#       <td id="T_7a608_row6_col1" class="data row6 col1" >5.38%</td>
#     </tr>
#     <tr>
#       <th id="T_7a608_level0_row7" class="row_heading level0 row7" >40+</th>
#       <td id="T_7a608_row7_col0" class="data row7 col0" >12</td>
#       <td id="T_7a608_row7_col1" class="data row7 col1" >2.08%</td>
#     </tr>
#   </tbody>
# </table>

# %%
age_purchase_count = age_demographics["Purchase ID"].count()
age_avg_purchase_price = round(age_demographics["Price"].mean(),2)
age_total_purchase_price = age_demographics["Price"].sum()
age_avg_total_purchase_per_person = age_total_purchase_price/total_count_age

age_purchase_analysis = pd.DataFrame({'Purchase Count':age_purchase_count,
                                    'Average Purchase Price': age_avg_purchase_price,
                                    'Total Purchase Price': age_total_purchase_price,
                                    'Total Purchase Price': age_avg_total_purchase_per_person
    
})
age_purchase_analysis.style.format({"Average Purchase Price":"${:.2f}",
                               "Total Purchase Price":"${:.2f}",
                               "Total Purchase Price":"${:.2f}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_e02c2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e02c2_level0_col0" class="col_heading level0 col0" >Purchase Count</th>
#       <th id="T_e02c2_level0_col1" class="col_heading level0 col1" >Average Purchase Price</th>
#       <th id="T_e02c2_level0_col2" class="col_heading level0 col2" >Total Purchase Price</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Age Range</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e02c2_level0_row0" class="row_heading level0 row0" ><10</th>
#       <td id="T_e02c2_row0_col0" class="data row0 col0" >23</td>
#       <td id="T_e02c2_row0_col1" class="data row0 col1" >$3.35</td>
#       <td id="T_e02c2_row0_col2" class="data row0 col2" >$4.54</td>
#     </tr>
#     <tr>
#       <th id="T_e02c2_level0_row1" class="row_heading level0 row1" >10-14</th>
#       <td id="T_e02c2_row1_col0" class="data row1 col0" >28</td>
#       <td id="T_e02c2_row1_col1" class="data row1 col1" >$2.96</td>
#       <td id="T_e02c2_row1_col2" class="data row1 col2" >$3.76</td>
#     </tr>
#     <tr>
#       <th id="T_e02c2_level0_row2" class="row_heading level0 row2" >15-19</th>
#       <td id="T_e02c2_row2_col0" class="data row2 col0" >136</td>
#       <td id="T_e02c2_row2_col1" class="data row2 col1" >$3.04</td>
#       <td id="T_e02c2_row2_col2" class="data row2 col2" >$3.86</td>
#     </tr>
#     <tr>
#       <th id="T_e02c2_level0_row3" class="row_heading level0 row3" >20-24</th>
#       <td id="T_e02c2_row3_col0" class="data row3 col0" >365</td>
#       <td id="T_e02c2_row3_col1" class="data row3 col1" >$3.05</td>
#       <td id="T_e02c2_row3_col2" class="data row3 col2" >$4.32</td>
#     </tr>
#     <tr>
#       <th id="T_e02c2_level0_row4" class="row_heading level0 row4" >25-29</th>
#       <td id="T_e02c2_row4_col0" class="data row4 col0" >101</td>
#       <td id="T_e02c2_row4_col1" class="data row4 col1" >$2.90</td>
#       <td id="T_e02c2_row4_col2" class="data row4 col2" >$3.81</td>
#     </tr>
#     <tr>
#       <th id="T_e02c2_level0_row5" class="row_heading level0 row5" >30-34</th>
#       <td id="T_e02c2_row5_col0" class="data row5 col0" >73</td>
#       <td id="T_e02c2_row5_col1" class="data row5 col1" >$2.93</td>
#       <td id="T_e02c2_row5_col2" class="data row5 col2" >$4.12</td>
#     </tr>
#     <tr>
#       <th id="T_e02c2_level0_row6" class="row_heading level0 row6" >35-39</th>
#       <td id="T_e02c2_row6_col0" class="data row6 col0" >41</td>
#       <td id="T_e02c2_row6_col1" class="data row6 col1" >$3.60</td>
#       <td id="T_e02c2_row6_col2" class="data row6 col2" >$4.76</td>
#     </tr>
#     <tr>
#       <th id="T_e02c2_level0_row7" class="row_heading level0 row7" >40+</th>
#       <td id="T_e02c2_row7_col0" class="data row7 col0" >13</td>
#       <td id="T_e02c2_row7_col1" class="data row7 col1" >$2.94</td>
#       <td id="T_e02c2_row7_col2" class="data row7 col2" >$3.19</td>
#     </tr>
#   </tbody>
# </table>

# %%
top_spender_df = purchase_data.groupby('SN')
purchase_count2 = purchase_data['SN'].value_counts()
spender_avg_purchase_price = top_spender_df['Price'].mean()
spender_total_purchase = top_spender_df['Price'].sum()
top_spender_analysis = pd.DataFrame({ 'Purchase Count': purchase_count2,
                                    'Average Purchase Price': spender_avg_purchase_price,
                                    'Total Purchase Value': spender_total_purchase

})
top_spender_analysis.sort_values(["Purchase Count", "Average Purchase Price", "Total Purchase Value"], ascending=False).head(5).style.format({"Average Purchase Price":"${:.2f}",
                                                                                            "Total Purchase Value": "${:.2f}"
})
# Out:
# <style type="text/css">
# </style>
# <table id="T_86d45">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_86d45_level0_col0" class="col_heading level0 col0" >Purchase Count</th>
#       <th id="T_86d45_level0_col1" class="col_heading level0 col1" >Average Purchase Price</th>
#       <th id="T_86d45_level0_col2" class="col_heading level0 col2" >Total Purchase Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_86d45_level0_row0" class="row_heading level0 row0" >Lisosia93</th>
#       <td id="T_86d45_row0_col0" class="data row0 col0" >5</td>
#       <td id="T_86d45_row0_col1" class="data row0 col1" >$3.79</td>
#       <td id="T_86d45_row0_col2" class="data row0 col2" >$18.96</td>
#     </tr>
#     <tr>
#       <th id="T_86d45_level0_row1" class="row_heading level0 row1" >Idastidru52</th>
#       <td id="T_86d45_row1_col0" class="data row1 col0" >4</td>
#       <td id="T_86d45_row1_col1" class="data row1 col1" >$3.86</td>
#       <td id="T_86d45_row1_col2" class="data row1 col2" >$15.45</td>
#     </tr>
#     <tr>
#       <th id="T_86d45_level0_row2" class="row_heading level0 row2" >Iral74</th>
#       <td id="T_86d45_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_86d45_row2_col1" class="data row2 col1" >$3.41</td>
#       <td id="T_86d45_row2_col2" class="data row2 col2" >$13.62</td>
#     </tr>
#     <tr>
#       <th id="T_86d45_level0_row3" class="row_heading level0 row3" >Chamjask73</th>
#       <td id="T_86d45_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_86d45_row3_col1" class="data row3 col1" >$4.61</td>
#       <td id="T_86d45_row3_col2" class="data row3 col2" >$13.83</td>
#     </tr>
#     <tr>
#       <th id="T_86d45_level0_row4" class="row_heading level0 row4" >Iskadarya95</th>
#       <td id="T_86d45_row4_col0" class="data row4 col0" >3</td>
#       <td id="T_86d45_row4_col1" class="data row4 col1" >$4.37</td>
#       <td id="T_86d45_row4_col2" class="data row4 col2" >$13.10</td>
#     </tr>
#   </tbody>
# </table>

# %%
popular_items = purchase_data.groupby(['Item ID', 'Item Name'])
pop_purchase_count = popular_items['Item ID'].count()
pop_items_price = round(popular_items['Price'].mean(),2)
pop_total_purchase = popular_items['Price'].sum()
popular_items_analysis = pd.DataFrame({'Purchase Count': pop_purchase_count,
                                        'Item Price': pop_items_price,
                                        'Total Purchase Value': pop_total_purchase

})
popular_items_analysis.sort_values(["Purchase Count"], ascending=False).head(5).style.format({"Item Price":"${:.2f}", "Total Purchase Value":"${:.2f}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_9cd0d">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9cd0d_level0_col0" class="col_heading level0 col0" >Purchase Count</th>
#       <th id="T_9cd0d_level0_col1" class="col_heading level0 col1" >Item Price</th>
#       <th id="T_9cd0d_level0_col2" class="col_heading level0 col2" >Total Purchase Value</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Item ID</th>
#       <th class="index_name level1" >Item Name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9cd0d_level0_row0" class="row_heading level0 row0" >92</th>
#       <th id="T_9cd0d_level1_row0" class="row_heading level1 row0" >Final Critic</th>
#       <td id="T_9cd0d_row0_col0" class="data row0 col0" >13</td>
#       <td id="T_9cd0d_row0_col1" class="data row0 col1" >$4.61</td>
#       <td id="T_9cd0d_row0_col2" class="data row0 col2" >$59.99</td>
#     </tr>
#     <tr>
#       <th id="T_9cd0d_level0_row1" class="row_heading level0 row1" >178</th>
#       <th id="T_9cd0d_level1_row1" class="row_heading level1 row1" >Oathbreaker, Last Hope of the Breaking Storm</th>
#       <td id="T_9cd0d_row1_col0" class="data row1 col0" >12</td>
#       <td id="T_9cd0d_row1_col1" class="data row1 col1" >$4.23</td>
#       <td id="T_9cd0d_row1_col2" class="data row1 col2" >$50.76</td>
#     </tr>
#     <tr>
#       <th id="T_9cd0d_level0_row2" class="row_heading level0 row2" >145</th>
#       <th id="T_9cd0d_level1_row2" class="row_heading level1 row2" >Fiery Glass Crusader</th>
#       <td id="T_9cd0d_row2_col0" class="data row2 col0" >9</td>
#       <td id="T_9cd0d_row2_col1" class="data row2 col1" >$4.58</td>
#       <td id="T_9cd0d_row2_col2" class="data row2 col2" >$41.22</td>
#     </tr>
#     <tr>
#       <th id="T_9cd0d_level0_row3" class="row_heading level0 row3" >132</th>
#       <th id="T_9cd0d_level1_row3" class="row_heading level1 row3" >Persuasion</th>
#       <td id="T_9cd0d_row3_col0" class="data row3 col0" >9</td>
#       <td id="T_9cd0d_row3_col1" class="data row3 col1" >$3.22</td>
#       <td id="T_9cd0d_row3_col2" class="data row3 col2" >$28.99</td>
#     </tr>
#     <tr>
#       <th id="T_9cd0d_level0_row4" class="row_heading level0 row4" >108</th>
#       <th id="T_9cd0d_level1_row4" class="row_heading level1 row4" >Extraction, Quickblade Of Trembling Hands</th>
#       <td id="T_9cd0d_row4_col0" class="data row4 col0" >9</td>
#       <td id="T_9cd0d_row4_col1" class="data row4 col1" >$3.53</td>
#       <td id="T_9cd0d_row4_col2" class="data row4 col2" >$31.77</td>
#     </tr>
#   </tbody>
# </table>

# %%
popular_items_analysis.sort_values(["Total Purchase Value", "Purchase Count","Item Price"], ascending=False).head(5).style.format({"Item Price":"${:.2f}", "Total Purchase Value":"${:.2f}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_0d6ed">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0d6ed_level0_col0" class="col_heading level0 col0" >Purchase Count</th>
#       <th id="T_0d6ed_level0_col1" class="col_heading level0 col1" >Item Price</th>
#       <th id="T_0d6ed_level0_col2" class="col_heading level0 col2" >Total Purchase Value</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Item ID</th>
#       <th class="index_name level1" >Item Name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0d6ed_level0_row0" class="row_heading level0 row0" >92</th>
#       <th id="T_0d6ed_level1_row0" class="row_heading level1 row0" >Final Critic</th>
#       <td id="T_0d6ed_row0_col0" class="data row0 col0" >13</td>
#       <td id="T_0d6ed_row0_col1" class="data row0 col1" >$4.61</td>
#       <td id="T_0d6ed_row0_col2" class="data row0 col2" >$59.99</td>
#     </tr>
#     <tr>
#       <th id="T_0d6ed_level0_row1" class="row_heading level0 row1" >178</th>
#       <th id="T_0d6ed_level1_row1" class="row_heading level1 row1" >Oathbreaker, Last Hope of the Breaking Storm</th>
#       <td id="T_0d6ed_row1_col0" class="data row1 col0" >12</td>
#       <td id="T_0d6ed_row1_col1" class="data row1 col1" >$4.23</td>
#       <td id="T_0d6ed_row1_col2" class="data row1 col2" >$50.76</td>
#     </tr>
#     <tr>
#       <th id="T_0d6ed_level0_row2" class="row_heading level0 row2" >82</th>
#       <th id="T_0d6ed_level1_row2" class="row_heading level1 row2" >Nirvana</th>
#       <td id="T_0d6ed_row2_col0" class="data row2 col0" >9</td>
#       <td id="T_0d6ed_row2_col1" class="data row2 col1" >$4.90</td>
#       <td id="T_0d6ed_row2_col2" class="data row2 col2" >$44.10</td>
#     </tr>
#     <tr>
#       <th id="T_0d6ed_level0_row3" class="row_heading level0 row3" >145</th>
#       <th id="T_0d6ed_level1_row3" class="row_heading level1 row3" >Fiery Glass Crusader</th>
#       <td id="T_0d6ed_row3_col0" class="data row3 col0" >9</td>
#       <td id="T_0d6ed_row3_col1" class="data row3 col1" >$4.58</td>
#       <td id="T_0d6ed_row3_col2" class="data row3 col2" >$41.22</td>
#     </tr>
#     <tr>
#       <th id="T_0d6ed_level0_row4" class="row_heading level0 row4" >103</th>
#       <th id="T_0d6ed_level1_row4" class="row_heading level1 row4" >Singed Scalpel</th>
#       <td id="T_0d6ed_row4_col0" class="data row4 col0" >8</td>
#       <td id="T_0d6ed_row4_col1" class="data row4 col1" >$4.35</td>
#       <td id="T_0d6ed_row4_col2" class="data row4 col2" >$34.80</td>
#     </tr>
#   </tbody>
# </table>
